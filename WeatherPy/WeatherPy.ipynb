# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
#!pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
now = datetime.datetime.now()
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
print(weather_api_key)
# Out:
# 9fc6f6a87957b5e0829be769afac7e46

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = "imperial"
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}"
weather_list = []
i=1
j=1
n=1
print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    if j % 50 ==0:
        time.sleep(60)
        n = n+1
        i = 1
    try:
        weather_dict = {}
        query_url = f"{url}&q={city}"
        #print(query_url)
        #print(requests.get(query_url))
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        temperature = weather_json["main"]["temp_max"]
        latitude = weather_json["coord"]["lat"]
        longitude = weather_json["coord"]["lon"]
        humidity = weather_json["main"]["humidity"]
        cloudy = weather_json["clouds"]["all"]
        wind = weather_json["wind"]["speed"]
        country = weather_json["sys"]["country"]
        #date = weather_json["sys"]["country"]
        weather_dict["Cities"] = city
        weather_dict["Max Temp"] = temperature
        weather_dict["Lat"] = latitude
        weather_dict["Lng"] = longitude
        weather_dict["Humidity"] = humidity
        weather_dict["Wind Speed"] = wind
        weather_dict["Cloudiness"] = cloudy
        weather_dict["Country"] = country
        weather_list.append(weather_dict)
        print(f"Processing Record {i} in set {n}| {city}")
        i=i+1
        j = j+1
    except:
        print("City not found. Skipping...")
        j = j+1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 in set 1| pathein
# Processing Record 2 in set 1| darnah
# Processing Record 3 in set 1| kaitangata
# Processing Record 4 in set 1| chokurdakh
# Processing Record 5 in set 1| parrita
# Processing Record 6 in set 1| rikitea
# Processing Record 7 in set 1| jamestown
# Processing Record 8 in set 1| caravelas
# Processing Record 9 in set 1| vetovo
# Processing Record 10 in set 1| hobart
# Processing Record 11 in set 1| saint-philippe
# Processing Record 12 in set 1| hasaki
# Processing Record 13 in set 1| vaxjo
# Processing Record 14 in set 1| avarua
# Processing Record 15 in set 1| emba
# Processing Record 16 in set 1| lata
# Processing Record 17 in set 1| mataura
# Processing Record 18 in set 1| yellowknife
# Processing Record 19 in set 1| kano
# Processing Record 20 in set 1| mason city
# Processing Record 21 in set 1| bagotville
# Processing Record 22 in set 1| esso
# Processing Record 23 in set 1| mayumba
# Processing Record 24 in set 1| ubinskoye
# Processing Record 25 in set 1| jieshi
# Processing Record 26 in set 1| ojuelos de jalisco
# Processing Record 27 in set 1| busselton
# Processing Record 28 in set 1| ushuaia
# City not found. Skipping...
# Processing Record 29 in set 1| piranshahr
# City not found. Skipping...
# Processing Record 30 in set 1| turukhansk
# Processing Record 31 in set 1| hilo
# Processing Record 32 in set 1| khakhea
# Processing Record 33 in set 1| lebu
# Processing Record 34 in set 1| port-gentil
# Processing Record 35 in set 1| baculin
# Processing Record 36 in set 1| ngaoundere
# Processing Record 37 in set 1| esperance
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 in set 1| taksimo
# Processing Record 39 in set 1| kahului
# Processing Record 40 in set 1| qaanaaq
# City not found. Skipping...
# Processing Record 41 in set 1| tuktoyaktuk
# Processing Record 42 in set 1| barrow
# Processing Record 43 in set 1| green river
# Processing Record 44 in set 1| vila franca do campo
# Processing Record 1 in set 2| saskylakh
# Processing Record 2 in set 2| thompson
# Processing Record 3 in set 2| quatre cocos
# Processing Record 4 in set 2| havre-saint-pierre
# Processing Record 5 in set 2| beringovskiy
# Processing Record 6 in set 2| pevek
# Processing Record 7 in set 2| lisala
# Processing Record 8 in set 2| kiama
# Processing Record 9 in set 2| tailai
# Processing Record 10 in set 2| cherskiy
# Processing Record 11 in set 2| bambous virieux
# Processing Record 12 in set 2| portland
# Processing Record 13 in set 2| oistins
# Processing Record 14 in set 2| mahebourg
# Processing Record 15 in set 2| gornopravdinsk
# Processing Record 16 in set 2| bredasdorp
# Processing Record 17 in set 2| tiznit
# Processing Record 18 in set 2| nhulunbuy
# Processing Record 19 in set 2| erice
# Processing Record 20 in set 2| carnarvon
# Processing Record 21 in set 2| vaini
# Processing Record 22 in set 2| asau
# Processing Record 23 in set 2| xinxiang
# City not found. Skipping...
# Processing Record 24 in set 2| constitucion
# Processing Record 25 in set 2| gardez
# Processing Record 26 in set 2| dong hoi
# Processing Record 27 in set 2| punta arenas
# City not found. Skipping...
# Processing Record 28 in set 2| bethel
# Processing Record 29 in set 2| hithadhoo
# Processing Record 30 in set 2| amapa
# Processing Record 31 in set 2| korla
# Processing Record 32 in set 2| dudinka
# Processing Record 33 in set 2| banda aceh
# Processing Record 34 in set 2| ribeira grande
# Processing Record 35 in set 2| port lincoln
# Processing Record 36 in set 2| east london
# Processing Record 37 in set 2| kondinskoye
# City not found. Skipping...
# Processing Record 38 in set 2| kirakira
# Processing Record 39 in set 2| kargasok
# Processing Record 40 in set 2| oranjestad
# Processing Record 41 in set 2| san patricio
# City not found. Skipping...
# Processing Record 42 in set 2| klaksvik
# Processing Record 43 in set 2| araouane
# Processing Record 44 in set 2| tias
# Processing Record 45 in set 2| bluff
# Processing Record 46 in set 2| bandarbeyla
# Processing Record 1 in set 3| sinnamary
# Processing Record 2 in set 3| luanda
# Processing Record 3 in set 3| alta floresta
# City not found. Skipping...
# Processing Record 4 in set 3| pangnirtung
# City not found. Skipping...
# Processing Record 5 in set 3| tasiilaq
# Processing Record 6 in set 3| yabelo
# Processing Record 7 in set 3| trinidad
# Processing Record 8 in set 3| kapaa
# Processing Record 9 in set 3| mar del plata
# Processing Record 10 in set 3| saint anthony
# Processing Record 11 in set 3| vitim
# Processing Record 12 in set 3| vardo
# City not found. Skipping...
# Processing Record 13 in set 3| victoria
# Processing Record 14 in set 3| ahuimanu
# Processing Record 15 in set 3| marmora
# Processing Record 16 in set 3| luderitz
# Processing Record 17 in set 3| geraldton
# Processing Record 18 in set 3| nome
# Processing Record 19 in set 3| bud
# Processing Record 20 in set 3| longyearbyen
# Processing Record 21 in set 3| paamiut
# Processing Record 22 in set 3| bengkulu
# Processing Record 23 in set 3| piacabucu
# Processing Record 24 in set 3| ilulissat
# Processing Record 25 in set 3| albania
# Processing Record 26 in set 3| boshnyakovo
# Processing Record 27 in set 3| lasa
# Processing Record 28 in set 3| talnakh
# Processing Record 29 in set 3| saint-leu
# Processing Record 30 in set 3| bilma
# Processing Record 31 in set 3| sokoni
# Processing Record 32 in set 3| albany
# Processing Record 33 in set 3| te anau
# Processing Record 34 in set 3| rameshki
# Processing Record 35 in set 3| georgetown
# Processing Record 36 in set 3| rundu
# Processing Record 37 in set 3| chirongui
# Processing Record 38 in set 3| san cristobal
# Processing Record 39 in set 3| minsk
# Processing Record 40 in set 3| rio grande city
# Processing Record 41 in set 3| ciudad bolivar
# City not found. Skipping...
# Processing Record 42 in set 3| pechora
# Processing Record 43 in set 3| bubaque
# Processing Record 44 in set 3| inongo
# Processing Record 45 in set 3| arraial do cabo
# City not found. Skipping...
# Processing Record 1 in set 4| tura
# Processing Record 2 in set 4| cayenne
# Processing Record 3 in set 4| cape town
# City not found. Skipping...
# Processing Record 4 in set 4| nanortalik
# Processing Record 5 in set 4| atar
# Processing Record 6 in set 4| andenes
# Processing Record 7 in set 4| labuhan
# Processing Record 8 in set 4| atuona
# City not found. Skipping...
# Processing Record 9 in set 4| kashary
# City not found. Skipping...
# Processing Record 10 in set 4| upernavik
# Processing Record 11 in set 4| san lawrenz
# Processing Record 12 in set 4| koslan
# Processing Record 13 in set 4| new norfolk
# Processing Record 14 in set 4| fare
# Processing Record 15 in set 4| arzgir
# Processing Record 16 in set 4| tiksi
# Processing Record 17 in set 4| pafos
# Processing Record 18 in set 4| moree
# Processing Record 19 in set 4| banga
# Processing Record 20 in set 4| keningau
# Processing Record 21 in set 4| arbuzynka
# Processing Record 22 in set 4| katsuura
# Processing Record 23 in set 4| sada
# Processing Record 24 in set 4| port alfred
# City not found. Skipping...
# Processing Record 25 in set 4| ballina
# Processing Record 26 in set 4| waingapu
# Processing Record 27 in set 4| yuanping
# Processing Record 28 in set 4| bitung
# Processing Record 29 in set 4| huntington
# Processing Record 30 in set 4| nouadhibou
# Processing Record 31 in set 4| puerto ayora
# Processing Record 32 in set 4| aizkraukle
# Processing Record 33 in set 4| sorland
# Processing Record 34 in set 4| namibe
# Processing Record 35 in set 4| port blair
# Processing Record 36 in set 4| lorengau
# Processing Record 37 in set 4| cortland
# Processing Record 38 in set 4| ponta do sol
# Processing Record 39 in set 4| karachi
# Processing Record 40 in set 4| torbay
# Processing Record 41 in set 4| yar-sale
# Processing Record 42 in set 4| huilong
# Processing Record 43 in set 4| totolapan
# Processing Record 44 in set 4| kaohsiung
# Processing Record 45 in set 4| horta
# Processing Record 46 in set 4| cap-aux-meules
# Processing Record 1 in set 5| grindavik
# Processing Record 2 in set 5| hermanus
# Processing Record 3 in set 5| nosy varika
# Processing Record 4 in set 5| fortuna
# Processing Record 5 in set 5| pochutla
# City not found. Skipping...
# Processing Record 6 in set 5| vostok
# Processing Record 7 in set 5| bairiki
# City not found. Skipping...
# Processing Record 8 in set 5| moville
# City not found. Skipping...
# Processing Record 9 in set 5| sioux lookout
# Processing Record 10 in set 5| puerto gaitan
# Processing Record 11 in set 5| uvat
# Processing Record 12 in set 5| praia
# Processing Record 13 in set 5| faanui
# Processing Record 14 in set 5| changji
# Processing Record 15 in set 5| kutum
# Processing Record 16 in set 5| khatanga
# City not found. Skipping...
# Processing Record 17 in set 5| kodiak
# Processing Record 18 in set 5| port hedland
# Processing Record 19 in set 5| codrington
# Processing Record 20 in set 5| taltal
# Processing Record 21 in set 5| kodinsk
# City not found. Skipping...
# Processing Record 22 in set 5| gogrial
# Processing Record 23 in set 5| ahipara
# City not found. Skipping...
# Processing Record 24 in set 5| chama
# Processing Record 25 in set 5| valdivia
# Processing Record 26 in set 5| kruisfontein
# Processing Record 27 in set 5| bayanday
# City not found. Skipping...
# Processing Record 28 in set 5| shchors
# Processing Record 29 in set 5| batagay
# Processing Record 30 in set 5| benguela
# Processing Record 31 in set 5| umm lajj
# City not found. Skipping...
# Processing Record 32 in set 5| pisco
# Processing Record 33 in set 5| khorixas
# Processing Record 34 in set 5| sao filipe
# City not found. Skipping...
# Processing Record 35 in set 5| berlevag
# Processing Record 36 in set 5| cheremshan
# Processing Record 37 in set 5| cabra
# Processing Record 38 in set 5| mangrol
# Processing Record 39 in set 5| chuy
# Processing Record 40 in set 5| sarahan
# Processing Record 41 in set 5| dingle
# Processing Record 1 in set 6| opuwo
# Processing Record 2 in set 6| itaituba
# Processing Record 3 in set 6| horomerice
# Processing Record 4 in set 6| kidal
# Processing Record 5 in set 6| meulaboh
# Processing Record 6 in set 6| hirara
# Processing Record 7 in set 6| kaeo
# Processing Record 8 in set 6| sheridan
# Processing Record 9 in set 6| bogorodskoye
# Processing Record 10 in set 6| manuk mangkaw
# Processing Record 11 in set 6| lompoc
# City not found. Skipping...
# Processing Record 12 in set 6| adrar
# Processing Record 13 in set 6| mezen
# Processing Record 14 in set 6| severo-kurilsk
# Processing Record 15 in set 6| udachnyy
# Processing Record 16 in set 6| poum
# City not found. Skipping...
# Processing Record 17 in set 6| souillac
# Processing Record 18 in set 6| santa cruz
# Processing Record 19 in set 6| shimoda
# Processing Record 20 in set 6| vaitape
# Processing Record 21 in set 6| padilla
# Processing Record 22 in set 6| kloulklubed
# Processing Record 23 in set 6| castro
# Processing Record 24 in set 6| lavrentiya
# Processing Record 25 in set 6| nilagiri
# Processing Record 26 in set 6| bonfim
# Processing Record 27 in set 6| dauriya
# Processing Record 28 in set 6| tres lagoas
# Processing Record 29 in set 6| orlik
# Processing Record 30 in set 6| sakaiminato
# Processing Record 31 in set 6| fukuchiyama
# Processing Record 32 in set 6| abu samrah
# Processing Record 33 in set 6| ornskoldsvik
# Processing Record 34 in set 6| morada nova
# Processing Record 35 in set 6| aktau
# Processing Record 36 in set 6| limbang
# Processing Record 37 in set 6| tuatapere
# City not found. Skipping...
# Processing Record 38 in set 6| saint-pierre
# Processing Record 39 in set 6| nigde
# Processing Record 40 in set 6| yinchuan
# Processing Record 41 in set 6| port elizabeth
# Processing Record 42 in set 6| sola
# Processing Record 43 in set 6| peru
# Processing Record 44 in set 6| nikolskoye
# Processing Record 45 in set 6| megion
# Processing Record 46 in set 6| lewisville
# Processing Record 47 in set 6| preobrazheniye
# Processing Record 1 in set 7| dwarka
# Processing Record 2 in set 7| suntar
# Processing Record 3 in set 7| scarborough
# Processing Record 4 in set 7| great falls
# Processing Record 5 in set 7| bichura
# Processing Record 6 in set 7| yerbogachen
# Processing Record 7 in set 7| vysokogornyy
# Processing Record 8 in set 7| itoman
# Processing Record 9 in set 7| novo aripuana
# Processing Record 10 in set 7| hailar
# Processing Record 11 in set 7| maceio
# Processing Record 12 in set 7| mount gambier
# Processing Record 13 in set 7| inta
# Processing Record 14 in set 7| ukiah
# Processing Record 15 in set 7| makakilo city
# Processing Record 16 in set 7| padang
# Processing Record 17 in set 7| makokou
# Processing Record 18 in set 7| kirensk
# City not found. Skipping...
# Processing Record 19 in set 7| tabas
# City not found. Skipping...
# Processing Record 20 in set 7| hadejia
# Processing Record 21 in set 7| butaritari
# Processing Record 22 in set 7| cocorit
# Processing Record 23 in set 7| dikson
# City not found. Skipping...
# Processing Record 24 in set 7| santa marta
# Processing Record 25 in set 7| marsa matruh
# Processing Record 26 in set 7| ojinaga
# City not found. Skipping...
# Processing Record 27 in set 7| iracoubo
# Processing Record 28 in set 7| nivala
# Processing Record 29 in set 7| yulara
# Processing Record 30 in set 7| launceston
# Processing Record 31 in set 7| fruitvale
# Processing Record 32 in set 7| ngunguru
# Processing Record 33 in set 7| sao joao da barra
# Processing Record 34 in set 7| khani
# Processing Record 35 in set 7| along
# Processing Record 36 in set 7| sao geraldo do araguaia
# Processing Record 37 in set 7| chizhou
# Processing Record 38 in set 7| taquari
# Processing Record 39 in set 7| provideniya
# Processing Record 40 in set 7| marrakesh
# Processing Record 41 in set 7| krasnoselkup
# Processing Record 42 in set 7| gasa
# Processing Record 43 in set 7| moose factory
# Processing Record 44 in set 7| lahij
# Processing Record 45 in set 7| newport
# Processing Record 46 in set 7| nalut
# Processing Record 1 in set 8| gamba
# Processing Record 2 in set 8| voi
# Processing Record 3 in set 8| san agustin
# Processing Record 4 in set 8| matamoros
# Processing Record 5 in set 8| ambon
# Processing Record 6 in set 8| taunggyi
# Processing Record 7 in set 8| muros
# Processing Record 8 in set 8| palmerston
# Processing Record 9 in set 8| namatanai
# Processing Record 10 in set 8| auki
# Processing Record 11 in set 8| mount isa
# Processing Record 12 in set 8| muzambinho
# Processing Record 13 in set 8| comodoro rivadavia
# Processing Record 14 in set 8| mgandu
# Processing Record 15 in set 8| aksarka
# Processing Record 16 in set 8| fairbanks
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 in set 8| leh
# Processing Record 18 in set 8| tessalit
# City not found. Skipping...
# Processing Record 19 in set 8| mitu
# Processing Record 20 in set 8| markova
# Processing Record 21 in set 8| sitka
# Processing Record 22 in set 8| srednekolymsk
# Processing Record 23 in set 8| blagoyevo
# Processing Record 24 in set 8| manono
# Processing Record 25 in set 8| saint george
# Processing Record 26 in set 8| buraydah
# Processing Record 27 in set 8| westport
# Processing Record 28 in set 8| bela
# Processing Record 29 in set 8| cidreira
# Processing Record 30 in set 8| ozark
# City not found. Skipping...
# Processing Record 31 in set 8| kununurra
# Processing Record 32 in set 8| kavieng
# Processing Record 33 in set 8| flinders
# Processing Record 34 in set 8| toshkivka
# Processing Record 35 in set 8| harindanga
# Processing Record 36 in set 8| innisfail
# Processing Record 37 in set 8| saint-joseph
# Processing Record 38 in set 8| magrath
# Processing Record 39 in set 8| half moon bay
# Processing Record 40 in set 8| laguna
# Processing Record 41 in set 8| bani
# Processing Record 42 in set 8| norman wells
# Processing Record 43 in set 8| novoilinsk
# Processing Record 44 in set 8| pokhara
# City not found. Skipping...
# Processing Record 45 in set 8| isangel
# Processing Record 1 in set 9| sisimiut
# Processing Record 2 in set 9| lindenberg
# Processing Record 3 in set 9| barra do garcas
# Processing Record 4 in set 9| soubre
# Processing Record 5 in set 9| plouzane
# Processing Record 6 in set 9| kirksville
# Processing Record 7 in set 9| ritchie
# Processing Record 8 in set 9| ketchikan
# Processing Record 9 in set 9| rongcheng
# Processing Record 10 in set 9| humboldt
# Processing Record 11 in set 9| seoul
# Processing Record 12 in set 9| bhola
# Processing Record 13 in set 9| imbituba
# Processing Record 14 in set 9| richards bay
# Processing Record 15 in set 9| grand gaube
# Processing Record 16 in set 9| ponta delgada
# Processing Record 17 in set 9| sishui
# Processing Record 18 in set 9| alofi
# Processing Record 19 in set 9| cookeville
# Processing Record 20 in set 9| kallaste
# Processing Record 21 in set 9| clyde river
# City not found. Skipping...
# Processing Record 22 in set 9| pyapon
# Processing Record 23 in set 9| grand-santi
# Processing Record 24 in set 9| giyon
# Processing Record 25 in set 9| viedma
# Processing Record 26 in set 9| grants
# Processing Record 27 in set 9| college
# Processing Record 28 in set 9| boddam
# Processing Record 29 in set 9| saint andrews
# Processing Record 30 in set 9| lingsugur
# Processing Record 31 in set 9| ingraj bazar
# Processing Record 32 in set 9| itarema
# Processing Record 33 in set 9| cotonou
# Processing Record 34 in set 9| coihaique
# Processing Record 35 in set 9| abramovka
# Processing Record 36 in set 9| petropavlovsk-kamchatskiy
# Processing Record 37 in set 9| chumikan
# Processing Record 38 in set 9| samarai
# Processing Record 39 in set 9| garissa
# Processing Record 40 in set 9| herat
# City not found. Skipping...
# Processing Record 41 in set 9| saldanha
# Processing Record 42 in set 9| eyl
# Processing Record 43 in set 9| bonavista
# Processing Record 44 in set 9| guanica
# City not found. Skipping...
# Processing Record 45 in set 9| mopti
# Processing Record 46 in set 9| kangra
# Processing Record 47 in set 9| martapura
# Processing Record 1 in set 10| mehamn
# Processing Record 2 in set 10| bluefields
# City not found. Skipping...
# Processing Record 3 in set 10| boralday
# Processing Record 4 in set 10| bathsheba
# Processing Record 5 in set 10| loa janan
# Processing Record 6 in set 10| deblin
# Processing Record 7 in set 10| funadhoo
# Processing Record 8 in set 10| tahoua
# Processing Record 9 in set 10| mildura
# Processing Record 10 in set 10| rawson
# Processing Record 11 in set 10| bahia honda
# Processing Record 12 in set 10| surt
# Processing Record 13 in set 10| walvis bay
# Processing Record 14 in set 10| jerez
# Processing Record 15 in set 10| corner brook
# Processing Record 16 in set 10| kenai
# Processing Record 17 in set 10| kabakovo
# Processing Record 18 in set 10| dossor
# Processing Record 19 in set 10| raghunathpur
# Processing Record 20 in set 10| pahrump
# Processing Record 21 in set 10| juneau
# Processing Record 22 in set 10| ushtobe
# Processing Record 23 in set 10| sarkand
# Processing Record 24 in set 10| bilibino
# Processing Record 25 in set 10| faya
# Processing Record 26 in set 10| nantucket
# Processing Record 27 in set 10| hendrina
# Processing Record 28 in set 10| fort nelson
# Processing Record 29 in set 10| porto nacional
# Processing Record 30 in set 10| chavakachcheri
# Processing Record 31 in set 10| asosa
# Processing Record 32 in set 10| aklavik
# Processing Record 33 in set 10| barcelos
# Processing Record 34 in set 10| road town
# Processing Record 35 in set 10| tabou
# Processing Record 36 in set 10| tilichiki
# Processing Record 37 in set 10| sangmelima
# Processing Record 38 in set 10| huarmey
# Processing Record 39 in set 10| bartica
# Processing Record 40 in set 10| madzhalis
# Processing Record 41 in set 10| stornoway
# Processing Record 42 in set 10| kikwit
# Processing Record 43 in set 10| angarsk
# Processing Record 44 in set 10| columbia
# Processing Record 45 in set 10| lekoni
# Processing Record 46 in set 10| anori
# Processing Record 47 in set 10| egvekinot
# Processing Record 48 in set 10| pallavaram
# Processing Record 49 in set 10| kolokani
# Processing Record 1 in set 11| baykit
# Processing Record 2 in set 11| inuvik
# Processing Record 3 in set 11| saharsa
# Processing Record 4 in set 11| inirida
# Processing Record 5 in set 11| santa cruz cabralia
# City not found. Skipping...
# Processing Record 6 in set 11| gidam
# Processing Record 7 in set 11| requena
# Processing Record 8 in set 11| kudahuvadhoo
# Processing Record 9 in set 11| maroantsetra
# City not found. Skipping...
# Processing Record 10 in set 11| hambantota
# Processing Record 11 in set 11| la ronge
# Processing Record 12 in set 11| keuruu
# Processing Record 13 in set 11| acapulco
# Processing Record 14 in set 11| roald
# Processing Record 15 in set 11| usinsk
# Processing Record 16 in set 11| palmer
# Processing Record 17 in set 11| narsaq
# Processing Record 18 in set 11| zhuanghe
# Processing Record 19 in set 11| larvik
# Processing Record 20 in set 11| weligama
# Processing Record 21 in set 11| waw
# City not found. Skipping...
# Processing Record 22 in set 11| mansa
# Processing Record 23 in set 11| campoverde
# Processing Record 24 in set 11| bhimavaram
# Processing Record 25 in set 11| santo antonio do ica
# Processing Record 26 in set 11| sevojno
# Processing Record 27 in set 11| mecayapan
# Processing Record 28 in set 11| jaisalmer
# Processing Record 29 in set 11| port shepstone
# Processing Record 30 in set 11| goussainville
# Processing Record 31 in set 11| manacapuru
# Processing Record 32 in set 11| noumea
# Processing Record 33 in set 11| adre
# Processing Record 34 in set 11| salalah
# City not found. Skipping...
# Processing Record 35 in set 11| whitehorse
# Processing Record 36 in set 11| sturgeon falls
# Processing Record 37 in set 11| emerald
# Processing Record 38 in set 11| saint-georges
# Processing Record 39 in set 11| rognan
# Processing Record 40 in set 11| shu
# Processing Record 41 in set 11| fort abbas
# Processing Record 42 in set 11| rio gallegos
# Processing Record 43 in set 11| vasalemma
# Processing Record 44 in set 11| rudbar
# Processing Record 45 in set 11| hue
# Processing Record 46 in set 11| sosnovo-ozerskoye
# Processing Record 1 in set 12| poso
# Processing Record 2 in set 12| guane
# Processing Record 3 in set 12| verkhoyansk
# Processing Record 4 in set 12| kota
# Processing Record 5 in set 12| pemangkat
# Processing Record 6 in set 12| gat
# Processing Record 7 in set 12| sainte-maxime
# Processing Record 8 in set 12| dingtao
# Processing Record 9 in set 12| kurilsk
# Processing Record 10 in set 12| dubbo
# Processing Record 11 in set 12| hedaru
# Processing Record 12 in set 12| santa flavia
# Processing Record 13 in set 12| glenwood springs
# Processing Record 14 in set 12| kanigoro
# Processing Record 15 in set 12| la asuncion
# Processing Record 16 in set 12| broome
# Processing Record 17 in set 12| oum hadjer
# Processing Record 18 in set 12| komsomolskiy
# Processing Record 19 in set 12| crystal beach
# City not found. Skipping...
# Processing Record 20 in set 12| coruripe
# Processing Record 21 in set 12| masiga
# Processing Record 22 in set 12| alice springs
# Processing Record 23 in set 12| vestmannaeyjar
# Processing Record 24 in set 12| traverse city
# Processing Record 25 in set 12| skhisma
# Processing Record 26 in set 12| leningradskiy
# Processing Record 27 in set 12| mareeba
# Processing Record 28 in set 12| marystown
# Processing Record 29 in set 12| aykhal
# Processing Record 30 in set 12| gargzdai
# Processing Record 31 in set 12| guilin
# Processing Record 32 in set 12| guatire
# Processing Record 33 in set 12| sorong
# Processing Record 34 in set 12| rovaniemi
# Processing Record 35 in set 12| san quintin
# Processing Record 36 in set 12| guadalajara
# Processing Record 37 in set 12| campbellford
# City not found. Skipping...
# Processing Record 38 in set 12| nekhayevskiy
# City not found. Skipping...
# Processing Record 39 in set 12| belmonte
# Processing Record 40 in set 12| billings
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 in set 12| ulaangom
# Processing Record 42 in set 12| maltahohe
# Processing Record 43 in set 12| naze
# Processing Record 44 in set 12| fayaoue
# Processing Record 45 in set 12| gubkinskiy
# Processing Record 1 in set 13| rocha
# Processing Record 2 in set 13| sabzevar
# Processing Record 3 in set 13| parkersburg
# City not found. Skipping...
# Processing Record 4 in set 13| rafaela
# Processing Record 5 in set 13| plettenberg bay
# Processing Record 6 in set 13| paragominas
# Processing Record 7 in set 13| tadine
# Processing Record 8 in set 13| colares
# Processing Record 9 in set 13| vilhena
# Processing Record 10 in set 13| mpika
# Processing Record 11 in set 13| marsh harbour
# Processing Record 12 in set 13| yumen
# Processing Record 13 in set 13| maniitsoq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 in set 13| aanekoski
# Processing Record 15 in set 13| ringkobing
# Processing Record 16 in set 13| wilmington
# Processing Record 17 in set 13| eydhafushi
# Processing Record 18 in set 13| lae
# Processing Record 19 in set 13| la grande
# Processing Record 20 in set 13| kushima

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
weather = pd.DataFrame(weather_list)
weather.to_csv("weather_info.csv")
weather.head()
# Out:
#        Cities  Max Temp    Lat     Lng  Humidity  Wind Speed  Cloudiness  \
# 0     pathein     84.15  16.78   94.73        77        8.81           2
# 1      darnah     70.81  32.77   22.64        68       21.21          44
# 2  kaitangata     52.00 -46.28  169.85        60        3.00           3
# 3  chokurdakh     20.75  70.63  147.92        96        5.03          82
# 4     parrita     78.80   9.52  -84.32        65        8.05          40
#
#   Country
# 0      MM
# 1      LY
# 2      NZ
# 3      RU
# 4      CR

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_too_high = weather.loc[weather["Humidity"]>100]

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_too_high
# Out:
# Empty DataFrame
# Columns: [Cities, Max Temp, Lat, Lng, Humidity, Wind Speed, Cloudiness, Country]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date = (now.strftime("%m/%d/%Y")) 
x = weather["Lat"]
y= weather["Max Temp"]
plt.scatter(x, y)
plt.title(f'City Latitude vs. Max Temperature ({date})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("../Images/Lat_vs_Temp")

# %% [markdown]
# * It appears that the closer a country's latitude is to the equator (0) the higher the Max Termperature is.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x = weather["Lat"]
y= weather["Humidity"]
plt.scatter(x, y)
plt.title(f'City Latitude vs. Humidity ({date})')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.grid()
plt.savefig("../Images/Lat_vs_Humidity")

# %% [markdown]
# * The most instances of humidit % between 0-40 occur between latitudes of 20-60.
# * There seem to be few countries around the equator with humidity % below 60.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x = weather["Lat"]
y= weather["Cloudiness"]
plt.scatter(x, y)
plt.title(f'City Latitude vs. Cloudiness ({date})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.grid()
plt.savefig("../Images/Lat_vs_Cloudiness")

# %% [markdown]
# * Cloudiness appears to have no relationship to latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x = weather["Lat"]
y= weather["Wind Speed"]
plt.scatter(x, y)
plt.title(f'City Latitude vs. Wind Speed ({date})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/Lat_vs_Wind Speed")

# %% [markdown]
# * Wind speed appears to have little relationship to latitude.
# * On the day these numbers were pulled (5/17/20) there appears to be few countries with wind speeds higher than 25 mph. Perhaps there were not many storms on this day.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def graph(x,y, x_label, y_label, equation_position, hemisphere):
    correlation = st.pearsonr(x, y)


    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x ,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,equation_position,fontsize=15,color="red")
    plt.ylabel(f'{y_label}')
    plt.xlabel(f'{x_label}')
    plt.title(f'{x_label} vs. {y_label} in the {hemisphere} hemisphere on ({date})')
    plt.savefig(f"../Images/{hemisphere}_{x_label}_vs_{y_label}")



    print(f"The correlation between both factors is {round(correlation[0],2)}")

    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
southern_hem = weather.loc[weather["Lat"]<0]
northern_hem = weather.loc[weather["Lat"]>=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph(northern_hem["Lat"],northern_hem["Max Temp"], "Latitude", "Max Temp (F)", (40,20), "Northern")
# Out:
# The correlation between both factors is -0.78

# %% [markdown]
# * There is a strong negative correlation between distance from the equator and Max Temperature.
# * This means the further you are from the equator, the colder you max temperature tends to be.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
graph(southern_hem["Lat"],southern_hem["Max Temp"], "Latitude", "Max Temp (F)", (-35, 45), "Southern")
# Out:
# The correlation between both factors is 0.83

# %% [markdown]
# * There is a strog positive correlation between Max Temp and Latitude when looking at the southern hemisphere.
# * This is because now as latitude values get larger they are getting closer to zero (or the equator) and tempertures are increasing

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph(northern_hem["Lat"],northern_hem["Humidity"], "Latitude", "Humidity %", (45, 20), "Northern")
# Out:
# The correlation between both factors is 0.01

# %% [markdown]
# * There appears to be little correlation between latitude and humidity in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
graph(southern_hem["Lat"],southern_hem["Humidity"], "Latitude", "Humidity %", (-20, 30), "Southern")
# Out:
# The correlation between both factors is 0.07

# %% [markdown]
# * There is still a very low correlation factor between humidity and latitude in the southern hemisphere.
# * There appear to be fewer countries with humidity below 40% in the southern hemisphere than in the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph(northern_hem["Lat"],northern_hem["Cloudiness"], "Latitude", "Cloudiness %", (20, 30), "Northern")
plt.savefig("../Images/NH_Cloudiness_vs_Lat")
# Out:
# The correlation between both factors is -0.02

# %% [markdown]
# * Cloudiness and latitude appear to have almost no correlation in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
graph(southern_hem["Lat"],southern_hem["Cloudiness"], "Latitude", "Cloudiness %", (-20, 30), "Southern")
# Out:
# The correlation between both factors is 0.1

# %% [markdown]
# * Cloudiness and latitude appear to have almost no correlation in the southern hemisphere as well.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph(northern_hem["Lat"],northern_hem["Wind Speed"], "Latitude", "Wind Speed (mph)", (20, 30), "Northern")
# Out:
# The correlation between both factors is -0.04

# %% [markdown]
# * Wind Speed appears to have no correlation with latitude in the northern hemisphere.
# * Very few cities reported winds higher than 25 mph in the northern hemisphere on 5/17/20.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
graph(southern_hem["Lat"],southern_hem["Wind Speed"], "Latitude", "Wind Speed (mph)", (-50, 20), "Southern")
# Out:
# The correlation between both factors is -0.02

# %% [markdown]
# * Wind Speed appears to have no correlation with latitude in the southern hemisphere.
# * Very few countries had wind speeds above 20 mph in the southern hemisphere. This shows a slightly smaller distribution than in the northern hemisphere. However, this could be because there are fewer cities from the random sample in the southern hemisphere.
